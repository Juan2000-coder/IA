# %% [markdown]
# # Trabajo Práctico Nº7
#
# ---
#
# <h2>Integrantes: </h2>
#
#   > *Borquez Juan*
#
#   > *Escobar Matías*
#
#   > *Hase Stephan*
#
#   > *Miranda Francisco*
#
#   > *Panonto Valentín*
#
# <h2> Temas Tratados en el Trabajo Práctico </h2>
#
# * Teoría de utilidad.
#
# * Toma de decisiones basadas en utilidad.
#
# * Valor de la información.
#
# * Ganancia y entropía.
#
# * Algoritmos basados en la teoría de la decisión.
#
# * Sistemas expertos.
#
# <h2> Ejercicios Teóricos </h2>
#
# 1. ¿Qué representa una función de utilidad?
#
#       Las preferencias de un agente respecto a ciertos estados del mundo se sustentan mediante una ***Función de Utilidad***, la cual asigna una cantidad numérica para expresar lo deseable que es un estado.
#
# 2. Describa los axiomas de la teoría de la utilidad.
#
#       **Ordenacion**: Dados dos estados cualesquiera, un agente racional debe ser capaz de, obien preferir uno de ellos, o bien establecer ambos igualmente preferibles. Es decir, el agente no puede evitar tomar una decisión.
#
#       (A > B) v (B > A) v (A ~ B)
#
#       **Transitividad**: Dados tres estados cualesquiera, si un agente prefiere A frente a B y a B sobre C, entonces el agente debe preferir A sobre C.
#
#       (A > B) ^ (B > C) -> (A > C)
#
#       **Continuidad**: Si existe algún estado B entre A y C en la relación de preferencia,entonces existe un valor de probabilidad p para el que el agente racional le es indiferente entre considerar como seguro el estado B y la lotería que establece el estado A con probabilidad p y al estado C con probabilidad 1-p.
#
#       (A > B > C) -> ∃ p [p,𝐴 ; 1−𝑝,𝐶] ~ 𝐵
#
#       **Sustitución**: Si un agente es indiferente entre dos loterías, A y B,entonces el agente es indiferente entre dos loterías más complejas en las que aparecen A y B.Esto es así, sin importar las probabilidades involucradas, ni el resto de resultados posibles en las loterías.
#
#       A ~ B -> [p,A ; 1-p,C] ~ [p,B ; 1-p,C]
#
#       **Monotonicidad**: Se supone que existen dos loterías que tienen dos resultados posibles e iguales, A y B. Entonces si un agente prefiere una lotería A frente a la lotería B, entonces el agente debe preferir la lotería que presenta una mayor probabilidad para A (y viceversa).
#
#       A > B -> (p ≥ q <-> [𝑝,𝐴 ; 1−𝑝,𝐵] ≥ [𝑞,𝐴 ; 1−𝑞,𝐵])
#
#       **Descomposición**: Las loterías compuestas pueden reducirse a una forma más simple empleando las propiedades de la teoría de la probabilidad.
#
#
# 3. Los boletos de una lotería cuestan un dólar. Hay dos juegos posibles con distintos premios: uno de 10 dólares con una probabilidad de uno entre 50 y otro de 1.000.000 dólares con una probabilidad de uno entre 2.000.000.
#
#
#         A: [1/50 , 10 ; 49/50 , 0]
#
#         B: [5e-7 , 1e6 ; (1-5e-7) , 0]
#
#
# &emsp;&emsp;3.1 ¿Cuál es el valor monetario esperado del boleto de lotería?
#
#         V(A) = 1/50 * 10 + 49/50 * 0 = 1/5 = 0.2
#
#         V(B) = 5e-7 * 1e6 + (1-5e-7) * 0 = 1/2 = 0.5
#
# &emsp;&emsp;3.2 ¿Cuándo es razonable comprar un boleto?
#
#         Es razonable comprar un boleto cuando el valor esperado de una de las loterias es menor que el de las otras.
#
#
# 4. Hay que reparar una máquina averiada y el mecánico diagnostica que si la avería es leve la reparación costará \$300, pero si es grave costará \$1.200. La probabilidad de que la avería sea grave es 2/3. También se ofrece la alternativa de comprar una máquina
# usada por \$600. Qué decisión se tomará si:
#
#
# &emsp;&emsp;4.1 La función de utilidad fuese la mostrada por el agente rojo.
#
# &emsp;&emsp;4.2 La función de utilidad fuese la mostrada por el agente verde.
#
#
# <h3> Resolución </h3>
#
#         A: [1/3 , 300  ;  2/3 , 1200]
#
#         B: [1 , 600]
#
#         V(A) = 1/3 * 300 + 2/3 * 1200 = 900
#
#         V(B) = 1 * 600 = 600
#
#         El rojo elegiría comprar la usada y el verde elegiría reparar.
#
#         Se entra con el 2/3 (peor escenario posible) y se mira el corte sobre las curvas de utilidad. los costes que se encuentran a la izquierda son "baratos" enotonces, el agente se arriesga al valor siguiente.
#
#         El rojo entonces opta por el de coste 600, loteria B, mietras que el verde opta por la loteria A. El agente rojo no se arriesga y el verde sí.
#
#
# ![Utilidad](https://drive.google.com/uc?export=view&id=1vNTlLArEhsxTOIvgs-NJ7NcE0B0JPJcw)
#
# 5. Una empresa minera quiere enviar a un robot recolector de materiales a visitar un planeta. El costo del viaje asciende a \$20.000.000. Tiene que decidir a qué planeta lo enviará de entre 5 opciones, sabiendo que uno de ellos contiene oro por un valor de \$100.000.000 y los no poseen nada de valor.<br>
# La Comisión Nacional del Espacio ofrece los resultados de un estudio sobre el planeta X en el que indica si hay o no oro; y vende dicha información por \$25.000.000. ¿Nos beneficia comprar dicha información?
#
# <h3> Resolución </h3>
#
#       Marte
#           Costo:    20M
#           Ganancia: 100M
#           Prob:     1/5
#           Cinf:     25M
#
#           E marte = 80M
#           E-marte = -20M
#
#           V(E marte) = 1/5 * 80M = 16M
#           V(E -marte) = 4/5 * -20M = -16M
#
#           Neto: 100M - 80M - 20M = $0
#
#
#           Entonces no conviene comprar la información, pq el informe vale 25M y el valor esperado es de 0. Conviene arriesgarse y apostar a ciegas. La ganancia va a ser mas grande si juegas sin apostar por el informe.
#
#           Si el precio del informe fuera de $1, la matematica tambien dice que no conviene comprar el informe, a pesar de que pagando 5 informes serían solo $5 y eso es razonablemente muy conveniente. No se obtendrá la ganancia maxima, como si lo sería explorar a ciegas, pero el valor es de $1, lo cual es muy conveniente si se razona el problema en términos de calidad, y no de cantidad.
#
#
# <h2> Ejercicios de Implementación </h2>
#
# 6. En unos laboratorios de un hospital se está investigando sobre una sustancia para la curación de una determinada enfermedad. Dicha sustancia ha sido inyectada en varias cobayas enfermas para verificar sus efectos. Los resultados de las pruebas realizadas se sintetizan en la siguiente tabla:
#
# <table><tr><td><b>Estado de la enfermedad</td><td><b>Concentración de la sustancia</td><td><b>Número de dosis</td><td><b>Condición física</td><td><b>Efecto</td></tr>
#
# <tr><td>Incipiente</td><td>75</td><td>70</td><td>Fuerte</td><td>Curación</td></tr>
#
# <tr><td>Incipiente</td><td>80</td><td>90</td><td>Fuerte</td><td>Defunción</td></tr>
#
# <tr><td>Incipiente</td><td>85</td><td>85</td><td>Débil</td><td>Defunción</td></tr>
#
# <tr><td>Incipiente</td><td>62</td><td>95</td><td>Débil</td><td>Defunción</td></tr>
#
# <tr><td>Incipiente</td><td>79</td><td>70</td><td>Débil</td><td>Curación</td></tr>
#
# <tr><td>Avanzado</td><td>72</td><td>90</td><td>Fuerte</td><td>Curación</td></tr>
#
# <tr><td>Avanzado</td><td>83</td><td>78</td><td>Débil</td><td>Curación</td></tr>
#
# <tr><td>Avanzado</td><td>64</td><td>66</td><td>Fuerte</td><td>Curación</td></tr>
#
# <tr><td>Avanzado</td><td>81</td><td>75</td><td>Débil</td><td>Curación</td></tr>
#
# <tr><td>Terminal</td><td>71</td><td>80</td><td>Fuerte</td><td>Defunción</td></tr>
#
# <tr><td>Terminal</td><td>65</td><td>70</td><td>Fuerte</td><td>Defunción</td></tr>
#
# <tr><td>Terminal</td><td>75</td><td>80</td><td>Débil</td><td>Curación</td></tr>
#
# <tr><td>Terminal</td><td>68</td><td>80</td><td>Débil</td><td>Curación</td></tr>
#
# <tr><td>Terminal</td><td>70</td><td>96</td><td>Débil</td><td>Curación</td></tr></table>
#
# Determine las reglas que rigen las condiciones en las que se ha de administrar una sustancia e implemente un sistema experto en CLIPS que determine si un sujeto resultará curado o no.
#
# <h3> Resolución </h3>
#
#       N: 14 (población)
#       C: 9  (cobayas curadas - resultados P: positivo)
#       n: 5  (cobayas muertas - resultados N: negativo)
#
#       -9/14 * log2(9/14) -5/14 * log2(5/14) = 0.94
#
#       E(Enf) = -5/14 * log2(5/14) -4/14 * log2(4/14) -5/14 * log2(5/14) = 1.58
#
#
#             -> < 70
#        CS   ->  70 <= x < 80
#             -> >=80
#
#       E(CS) = -4/14 * log2(4/14) -6/14 * log2(6/14) -4/14 * log2(4/14) = 1.56
#
#
#        nd   -> >= 70
#             ->  < 70
#
#       E(nd) = -13/14 * log2(13/14) -1/14 * log2(1/14) = 0.37
#
#
#       E(cf) = -6/14 * log2(6/14) -8/14 * log2(8/14) = 0.99
#
#       Siempre que podamos definir más rangos, vamos a poder mejorar el problema, pero si el usuario del SE luego tiene más rangos para ver, puede resultar perjudicial a la hora de tomar decisiones concretas.
#
#
#       Numericamente el "Estado de enfermedad" es el que mayor categoriza.
#       Planteamos entonces los siguientes subcasos:
#           Incipiente:     -> nd   ->  > 70:   Defuncion
#                                   -> =< 70:   Cura
#
#           Avanzado:       -> Cura
#
#           Terminal:       -> cd   -> Fuerte: Defunción
#                                   -> Débil:  Cura
#
#
#       R1: if( E =  'Avanzado')
#             then Cura, Aplicar Vacuna
#
#       R2: if( E =  'Insipiente')
#             then R3, R4
#
#       R3: if( nd =  <= 70)
#             then Cura, Aplicar Vacuna
#
#       R4: if( nd >  70)
#             then Defunsión, -Aplicar Vacuna
#
#       R5: if( E =  'Terminal')
#             then R6, R7
#
#       R6: if( cf =  'Débil')
#             then Cura, Aplicar Vacuna
#
#       R7: if( E =  'Fuerte')
#             then Defunsión, -Aplicar Vacuna
#
#
# Ejemplo de uso de código en CLIPS:
#   <div align="center">
#   <img src="https://drive.google.com/uc?id=1sELE-3I5n43EwrW-D4f-z2WIrpxQnogt" alt="Resolución Ejercicio 6. Ejemplo 1" width="80%" />
#   </div>
#
#   <div align="center">
#   <img src="https://drive.google.com/uc?id=1vWUYKB09yj1hVMbRN-CF2hkE_RaLNQdm" alt="Resolución Ejercicio 6. Ejemplo 2" width="80%" />
#   </div>
#
#
# # Bibliografía
#
# [Russell, S. & Norvig, P. (2004) _Inteligencia Artificial: Un Enfoque Moderno_. Pearson Educación S.A. (2a Ed.) Madrid, España](https://www.academia.edu/8241613/Inteligencia_Aritificial_Un_Enfoque_Moderno_2da_Edici%C3%B3n_Stuart_J_Russell_y_Peter_Norvig)
#
# [Poole, D. & Mackworth, A. (2017) _Artificial Intelligence: Foundations of Computational Agents_. Cambridge University Press (3a Ed.) Vancouver, Canada](https://artint.info/3e/html/ArtInt3e.html)
